% %% [markdown]
% # MATLAB-Jupyter test

% %% [markdown]
% ## simple plot

% %%
x = 0:pi/100:2*pi;
y = sin(x);

% %%
plot(x,y)

% %% [markdown]
% ## Another plot

% %%
x = linspace(-2*pi,2*pi);
y1 = sin(x);
y2 = cos(x);

plot(x,y1,x,y2)

% %% [markdown]
% ## Heading 2

% %% [markdown]
% balabala

% %% [markdown]
% ### Heading 3

% %% [markdown]
% balabala

% %% [markdown]
% #### Heading 4

% %% [markdown]
% balabala
